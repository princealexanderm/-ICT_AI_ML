# %% [markdown]
# <a href="https://colab.research.google.com/github/princealexanderm/-ICT_AI_ML/blob/main/ICT_AI_ML__Assignment_01_Python_Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment-1

# %% [markdown]
# Assignment 01 - Python Libraries
# Dear all,
# Welcome to Assignment 01 - Machine Learning Libraries
#
#
# Things to Note:
#
# * The question and dataset is added here.
# * Create a repository in GitHub account  as "Public".
# * Upload the notebook file(.ipynb) to the repository.
# * Please make sure that you are uploading the notebook file including the outputs as well.
# * Share the link of this notebook from GitHub in the online text editor provided in Paatshala.
#
#
# Due Date: 3 April 2025 by 8.30 PM

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##1.Read the dataset to python environment

# %%
import pandas as pd
df=pd.read_csv('/content/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ##2. Display the columns in the dataset

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ##3. Calculate the mean of each column of the dataset.

# %%
Pregnancies_mean=df['Pregnancies'].mean()
print('Pregnancies_mean=',Pregnancies_mean)
# Out:
# Pregnancies_mean= 3.8450520833333335

# %%
Glucose_mean=df['Glucose'].mean()
print('Glucose_mean=',Glucose_mean)
# Out:
# Glucose_mean= 120.89453125

# %%
BloodPressure_mean=df['BloodPressure'].mean()
print('BloodPressure_mean=',BloodPressure_mean)
# Out:
# BloodPressure_mean= 69.10546875

# %%
SkinThickness_mean=df['SkinThickness'].mean()
print('SkinThickness_mean=',SkinThickness_mean)
# Out:
# SkinThickness_mean= 20.536458333333332

# %%
Insulin_mean=df['Insulin'].mean()
print('Insulin_mean=',Insulin_mean)
# Out:
# Insulin_mean= 79.79947916666667

# %%
BMI_mean=df['BMI'].mean()
print('BMI_mean=',BMI_mean)
# Out:
# BMI_mean= 31.992578124999998

# %%
DiabetesPedigreeFunction_mean=df['DiabetesPedigreeFunction'].mean()
print('DiabetesPedigreeFunction_mean=',DiabetesPedigreeFunction_mean)
# Out:
# DiabetesPedigreeFunction_mean= 0.47187630208333325

# %%
Age_mean=df['Age'].mean()
print('Age_mean=',Age_mean)
# Out:
# Age_mean= 33.240885416666664

# %%
Outcome_mean=df['Outcome'].mean()
print('Outcomee_mean=',Outcome_mean)
# Out:
# Outcomee_mean= 0.3489583333333333

# %% [markdown]
# ##4. Check for the null values present in the dataset.

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### No null values

# %% [markdown]
# ##5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# ###Distribution of Age

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Age
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ###Relationship between Glucose and Outcome

# %%
# Relationship between Glucose and Outcome
plt.figure(figsize=(8, 6))
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title('Glucose Levels vs. Outcome')
plt.xlabel('Outcome (0 = No Diabetes, 1 = Diabetes)')
plt.ylabel('Glucose Level')
plt.show()

# %% [markdown]
# ###Correlation Matrix Heatmap

# %%
# Correlation Matrix Heatmap
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Diabetes Features')
plt.show()

# %% [markdown]
# ### Univariate analysis of all columns except target

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and it's already loaded

plt.figure(figsize=(20, 10))

# Subplot for Pregnancies
plt.subplot(2, 4, 1)
sns.histplot(df['Pregnancies'], kde=True)
plt.title('Pregnancies')

# Subplot for Glucose
plt.subplot(2, 4, 2)
sns.histplot(df['Glucose'], kde=True)
plt.title('Glucose')

# Subplot for BloodPressure
plt.subplot(2, 4, 3)
sns.histplot(df['BloodPressure'], kde=True)
plt.title('BloodPressure')

# Subplot for SkinThickness
plt.subplot(2, 4, 4)
sns.histplot(df['SkinThickness'], kde=True)
plt.title('SkinThickness')

# Subplot for Insulin
plt.subplot(2, 4, 5)
sns.histplot(df['Insulin'], kde=True)
plt.title('Insulin')

# Subplot for BMI
plt.subplot(2, 4, 6)
sns.histplot(df['BMI'], kde=True)
plt.title('BMI')

# Subplot for DiabetesPedigreeFunction
plt.subplot(2, 4, 7)
sns.histplot(df['DiabetesPedigreeFunction'], kde=True)
plt.title('DiabetesPedigreeFunction')
# Out:
# Text(0.5, 1.0, 'DiabetesPedigreeFunction')
